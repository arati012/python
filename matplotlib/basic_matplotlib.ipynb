# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### graph
# ##### plot
# ##### scallater
# ##### hist
# ##### bar
# ##### pie

# %% [markdown]
# ## plot

# %%
xpoint=np.array([0,6])
ypoint=np.array([0,250])
plt.plot(xpoint,ypoint)
plt.show()

# %%
xpoint=np.array([0,6])
ypoint=np.array([0,250])
plt.plot(xpoint,ypoint,'o') # o is used for scatter plot/no line
plt.show()

# %%
xpoint=np.array([1,8])  # 1 point the take it y
plt.plot(xpoint,marker='o')
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
plt.plot(xpoint, marker='o')
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
plt.plot(xpoint, marker='*')
plt.show()

# %%
xpoint=np.array([1,8,4 ,5])  
plt.plot(xpoint,'o:b')
plt.show()# o is used to create scatter plot and : is used to create black line

# %%
xpoint =np.array([1,8,4 ,5 ])
plt.plot(xpoint, marker='o', ms = 30) # ms:marker size
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
plt.plot(xpoint, marker='*', ms = 30,mec = 'r') # mec:marker edge colour
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
plt.plot(xpoint, marker='*', ms = 30,mec = 'r',mfc = 'g')
plt.show() # mfc: marker face colour

# %%
xpoint=np.array([1,8,4,5])  
plt.plot(xpoint,ls='dotted')  # ls: line style
plt.show()

# %%
xpoint=np.array([1,8,4,5])  
plt.plot(xpoint,ls='dashed')
plt.show()

# %%
xpoint=np.array([1,8,4,5])  
plt.plot(xpoint,linewidth=5)
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
ypoint =np.array([2,5,8 ,4 ])
plt.plot(xpoint)
plt.plot(ypoint)
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
ypoint =np.array([2,5,8 ,4 ])
plt.xlabel('Arati')
plt.ylabel('Anchal')
plt.plot(xpoint)
plt.plot(ypoint)
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
ypoint =np.array([2,5,8 ,4 ])
plt.title('Arati and Anchal dono data science pd rhe hai ')
plt.xlabel('Arati')
plt.ylabel('Anchal')
plt.plot(xpoint)
plt.plot(ypoint)
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
ypoint =np.array([2,5,8 ,4 ])
plt.title('Arati and Anchal dono data science pd rhe hai ')
plt.xlabel('Arati')
plt.ylabel('Anchal')
plt.grid() # grid for boxes

plt.plot(xpoint)
plt.plot(ypoint)
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])
plt.subplot(1,2,1)
plt.plot(x,y)
x = np.array([1,2,3,4,5])
y = np.array([1,8,27,64,125])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Scatter plot

# %%
# Scatter plot
x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])
plt.scatter(x,y)
plt.show()

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])
plt.scatter(x,y)


x1 = np.array([1,2,3,4,5])
y1 = np.array([1,8,27,64,125])
plt.scatter(x1,y1)
plt.show()

# %%
x = np.array([1,2,3,4,5])  #(1,1),(2,4)
y = np.array([1,4,9,16,25])
colour  = np.array(['red','green','blue','yellow','black'])
plt.scatter(x,y,c= colour)
plt.show()

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])
colour  = np.array(['red','green','blue','yellow','black'])
plt.scatter(x,y,c= colour , alpha= 0.5)
plt.show()

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])
colour  = np.array(['red','green','blue','yellow','black'])
size = np.array([10,20,30,40,50])
plt.scatter(x,y,c= colour , s = size , alpha= 0.5)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y, s = sizes, c = c )
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y,alpha=0.5, s = sizes, c = c )
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y,alpha=0.5, s = sizes, c = c, cmap='coolwarm' ) # camap = color map, viridis, nipy_spectral, coolwarm
plt.colorbar()
plt.show()
# Out:
# C:\Users\Jyoti Kumari\AppData\Local\Temp\ipykernel_22792\2633006295.py:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y,alpha=0.5, s = sizes, c = c, cmap='coolwarm' ) # camap = color map, viridis, nipy_spectral, coolwarm

# %% [markdown]
# ## Barplot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y)        # bar is used to create bar chart
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.barh(x,y)        # bar is used to create bar chart
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y, color = 'green')        # bar is used to create bar chart
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y, color = 'green' , width=0.1)        # bar is used to create bar chart
plt.show()

# %%
x =np.random.normal(170,10,250)
x
# Out:
# array([170.65064572, 166.44551716, 166.79035326, 160.82670707,
#        193.19708213, 186.31474855, 164.8153569 , 182.97768624,
#        166.49287392, 182.51636209, 168.18926219, 183.68501988,
#        159.13378469, 169.69519399, 166.24946985, 169.07041243,
#        162.22015467, 180.81687713, 157.39274158, 163.70806618,
#        169.66369084, 183.06236448, 165.47426037, 172.85396224,
#        163.54452164, 162.57512528, 174.8497451 , 168.41835762,
#        171.83775263, 165.80026823, 171.13769616, 172.51340345,
#        164.95752952, 174.48296253, 176.69969772, 171.1940385 ,
#        171.54237659, 161.74199967, 164.63275145, 181.97333542,
#        173.7494494 , 177.86004508, 158.44823572, 147.81556095,
#        171.00071544, 147.79232886, 176.34540105, 171.44631786,
#        172.02317002, 178.80947877, 155.70919943, 176.3831905 ,
#        171.59426254, 183.85262433, 168.08286214, 163.6784979 ,
#        173.91550247, 158.12000797, 159.87090135, 159.84694337,
# ...

# %%
plt.hist(x)
# Out:
# (array([ 2.,  4., 20., 37., 64., 57., 33., 24.,  4.,  5.]),
#  array([138.61586181, 144.54252688, 150.46919196, 156.39585704,
#         162.32252211, 168.24918719, 174.17585227, 180.10251734,
#         186.02918242, 191.9558475 , 197.88251257]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## PIE

# %%
x = np.array([1,2,3,4])
plt.pie(x)  
plt.show()

# %%
x = np.array([1,2,3,4])
mylabels = ['apples','bananas','cherries','dates']
plt.pie(x, labels = mylabels, startangle=90)  
plt.show()

# %%
x = np.array([1,2,3,4])
mylabels = ['apples','bananas','cherries','dates']
myexplode = [0.2,0,0,0]
plt.pie(x, labels = mylabels, startangle=90, explode=myexplode)  
plt.show()

# %%
x = np.array([1,2,3,4])
mylabels = ['apples','bananas','cherries','dates']
myexplode = [0.2,0,0,0]
plt.pie(x, labels = mylabels, startangle=90, explode=myexplode, shadow=True)  
plt.show()

# %%
x = np.array([1,2,3,4])
mylabels = ['apples','bananas','cherries','dates']
colour = ['red','green','blue','yellow']
myexplode = [0.2,0,0,0]
plt.pie(x, labels = mylabels, startangle=90, explode=myexplode, shadow=True, colors=colour)  
plt.show()

# %%
x = np.array([1,2,3,4])
mylabels = ['apples','bananas','cherries','dates']
colour = ['red','green','blue','yellow']
myexplode = [0.2,0,0,0]
plt.pie(x, labels = mylabels, startangle=90, explode=myexplode, shadow=True, colors=colour, autopct='%1.1f%%')  
plt.show()

# %%
x = np.array([1,2,3,4])
mylabels = ['apples','bananas','cherries','dates']
colour = ['red','green','blue','yellow']
myexplode = [0.2,0,0,0]
plt.pie(x, labels = mylabels, startangle=90, explode=myexplode, shadow=True, colors=colour, autopct='%1.1f%%')  
plt.legend(title = 'My pie chart')
plt.show()
