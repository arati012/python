# %% [markdown]
# In programming, pandas is a powerful data analysis and manipulation library used in python . it's widely used for handling structure data like tables or speadsheets

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\Jyoti Kumari\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
print("hello")
# Out:
# hello

# %%
df=pd.read_csv(r"C:\Users\Jyoti Kumari\OneDrive\Desktop\python\pandas\laptop_price_pridiction\laptop_data_cleaned.csv")

# %%
df
# Out:
#      Company            TypeName  Ram  Weight      Price  TouchScreen  Ips  \
# 0      Apple           Ultrabook    8    1.37  11.175755            0    1
# 1      Apple           Ultrabook    8    1.34  10.776777            0    0
# 2         HP            Notebook    8    1.86  10.329931            0    0
# 3      Apple           Ultrabook   16    1.83  11.814476            0    1
# 4      Apple           Ultrabook    8    1.37  11.473101            0    1
# ...      ...                 ...  ...     ...        ...          ...  ...
# 1268    Asus            Notebook    4    2.20  10.555257            0    0
# 1269  Lenovo  2 in 1 Convertible    4    1.80  10.433899            1    1
# 1270  Lenovo  2 in 1 Convertible   16    1.30  11.288115            1    1
# 1271  Lenovo            Notebook    2    1.50   9.409283            0    0
# 1272      HP            Notebook    6    2.19  10.614129            0    0
#
# ...

# %%
dataset=r"C:\Users\Jyoti Kumari\OneDrive\Desktop\python\pandas\laptop_price_pridiction\laptop_data_cleaned.csv"

# %%
data_set=pd.read_csv(dataset)

# %%
data_set
# Out:
#      Company            TypeName  Ram  Weight      Price  TouchScreen  Ips  \
# 0      Apple           Ultrabook    8    1.37  11.175755            0    1
# 1      Apple           Ultrabook    8    1.34  10.776777            0    0
# 2         HP            Notebook    8    1.86  10.329931            0    0
# 3      Apple           Ultrabook   16    1.83  11.814476            0    1
# 4      Apple           Ultrabook    8    1.37  11.473101            0    1
# ...      ...                 ...  ...     ...        ...          ...  ...
# 1268    Asus            Notebook    4    2.20  10.555257            0    0
# 1269  Lenovo  2 in 1 Convertible    4    1.80  10.433899            1    1
# 1270  Lenovo  2 in 1 Convertible   16    1.30  11.288115            1    1
# 1271  Lenovo            Notebook    2    1.50   9.409283            0    0
# 1272      HP            Notebook    6    2.19  10.614129            0    0
#
# ...

# %%
df=pd.read_csv("laptop_data_cleaned.csv")

# %%
df
# Out:
#      Company            TypeName  Ram  Weight      Price  TouchScreen  Ips  \
# 0      Apple           Ultrabook    8    1.37  11.175755            0    1
# 1      Apple           Ultrabook    8    1.34  10.776777            0    0
# 2         HP            Notebook    8    1.86  10.329931            0    0
# 3      Apple           Ultrabook   16    1.83  11.814476            0    1
# 4      Apple           Ultrabook    8    1.37  11.473101            0    1
# ...      ...                 ...  ...     ...        ...          ...  ...
# 1268    Asus            Notebook    4    2.20  10.555257            0    0
# 1269  Lenovo  2 in 1 Convertible    4    1.80  10.433899            1    1
# 1270  Lenovo  2 in 1 Convertible   16    1.30  11.288115            1    1
# 1271  Lenovo            Notebook    2    1.50   9.409283            0    0
# 1272      HP            Notebook    6    2.19  10.614129            0    0
#
# ...

# %%
total=pd.read_csv("laptopPrice.csv")

# %%
total
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
total.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
total.tail()
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 818  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 819  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 820  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 821  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 822   512 GB  0 GB      DOS  64-bit            0 GB  ThinNlight  No warranty
#
# ...

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
total.shape  # row,column
# Out:
# (823, 19)

# %%
total.describe() #summary
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
total.columns   #list of column
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
total
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
total['brand'].value_counts()
# Out:
# brand
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: count, dtype: int64

# %%
total['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
total['brand'].nunique()
# Out:
# 8

# %%
total['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
total['processor_brand'].nunique()
# Out:
# 3

# %%
total.duplicated().sum()
# Out:
# np.int64(21)

# %%
total.drop_duplicates(inplace=True)  # remove duplicate

# %%
total.duplicated().sum()
# Out:
# np.int64(0)

# %%
total.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
total['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
total['brand']=="APPLE"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Name: brand, Length: 802, dtype: bool

# %%
apple=total[total['brand']=="APPLE"]

# %%
apple
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# 607  APPLE              M1             M1            10th   8 GB     DDR4
# 608  APPLE              M1             M1            10th   8 GB     DDR4
# 609  APPLE              M1             M1            10th   8 GB     DDR4
# ...

# %%
apple.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count      23.000000          23.000000          23.000000
# mean   157081.304348         853.652174          84.826087
# std     54370.286948        1875.694747         174.698611
# min     85990.000000           3.000000           1.000000
# 25%    118990.000000          42.000000           5.000000
# 50%    149990.000000         108.000000          13.000000
# 75%    179990.000000         640.000000          70.000000
# max    309990.000000        6725.000000         629.000000

# %%
apple['ram_gb'].unique()
# Out:
# array(['8 GB', '16 GB', '4 GB', '32 GB'], dtype=object)

# %%
apple_8gb=apple[apple['ram_gb']=='8 GB']

# %%
apple_8gb
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 607  APPLE              M1             M1            10th   8 GB     DDR4
# 608  APPLE              M1             M1            10th   8 GB     DDR4
# 609  APPLE              M1             M1            10th   8 GB     DDR4
# 610  APPLE              M1             M1            10th   8 GB     DDR4
# 611  APPLE              M1             M1            10th   8 GB     DDR4
# 617  APPLE              M1             M1            10th   8 GB     DDR4
#
#          ssd   hdd   os  os_bit graphic_card_gb  weight warranty Touchscreen  \
# ...

# %%
apple_8gb['processor_brand'].unique()
# Out:
# array(['Intel', 'M1'], dtype=object)

# %%
apple_8gb_intel_brand=apple_8gb[apple_8gb['processor_brand']=='Intel']

# %%
apple_8gb_intel_brand
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
#
#         ssd   hdd   os  os_bit graphic_card_gb  weight warranty Touchscreen  \
# 309  512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 310  512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
#
#     msoffice   Price   rating  Number of Ratings  Number of Reviews
# 309       No  159990  4 stars                 32                  5
# 310       No  172090  4 stars                108                 13

# %%
total['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
hp=total[total['brand']=="HP"]

# %%
hp
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 15     HP           Intel        Core i3            11th   8 GB     DDR4
# 16     HP           Intel        Core i5            11th   8 GB     DDR4
# 18     HP           Intel   Celeron Dual   Not Available   8 GB     DDR4
# 22     HP           Intel        Core i3             7th   4 GB     DDR4
# 23     HP           Intel        Core i5             7th   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 776    HP             AMD        Ryzen 7   Not Available  16 GB     DDR4
# 777    HP             AMD        Ryzen 7   Not Available  16 GB     DDR4
# 782    HP             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 792    HP             AMD        Ryzen 7   Not Available  16 GB     DDR4
# 807    HP             AMD        Ryzen 9   Not Available   4 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
hp.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     136.000000         136.000000         136.000000
# mean    73640.272059         447.198529          50.485294
# std     36625.297509        1073.305823         121.424995
# min     26470.000000           0.000000           0.000000
# 25%     47690.000000           1.500000           0.000000
# 50%     59999.000000          39.500000           5.000000
# 75%     92247.500000         314.250000          42.750000
# max    239759.000000        7291.000000         895.000000

# %%
hp_intel=hp[hp['processor_brand']=='Intel']

# %%
hp_intel
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 15     HP           Intel        Core i3            11th   8 GB     DDR4
# 16     HP           Intel        Core i5            11th   8 GB     DDR4
# 18     HP           Intel   Celeron Dual   Not Available   8 GB     DDR4
# 22     HP           Intel        Core i3             7th   4 GB     DDR4
# 23     HP           Intel        Core i5             7th   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 569    HP           Intel        Core i7            11th  16 GB  LPDDR4X
# 572    HP           Intel        Core i7            11th  16 GB     DDR4
# 573    HP           Intel        Core i7            11th  16 GB     DDR4
# 578    HP           Intel        Core i7             8th  16 GB     DDR4
# 626    HP           Intel   Pentium Quad   Not Available   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
hp_intel_4gb=hp_intel[hp_intel['ram_gb']=='4 GB']

# %%
hp_intel_4gb
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 22     HP           Intel        Core i3             7th   4 GB     DDR4
# 23     HP           Intel        Core i5             7th   4 GB     DDR4
# 57     HP           Intel        Core i3            11th   4 GB     DDR4
# 72     HP           Intel        Core i3            11th   4 GB     DDR4
# 75     HP           Intel        Core i3            11th   4 GB     DDR4
# 85     HP           Intel        Core i3             8th   4 GB     DDR4
# 114    HP           Intel        Core i3            11th   4 GB     DDR4
# 115    HP           Intel        Core i3            10th   4 GB     DDR4
# 116    HP           Intel        Core i3            11th   4 GB     DDR4
# 118    HP           Intel        Core i3            11th   4 GB     DDR4
# 123    HP           Intel        Core i3            11th   4 GB     DDR4
# 124    HP           Intel        Core i3            11th   4 GB     DDR4
# ...

# %%
hp_intel['ram_gb'].unique()
# Out:
# array(['8 GB', '4 GB', '16 GB'], dtype=object)

# %%
total
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
asus=total[total['brand']=="ASUS"]

# %%
asus
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 817  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# ...

# %%
asus_intl=asus[asus['processor_brand']=='Intel']

# %%
asus_intl
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 630  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 632  ASUS           Intel   Pentium Quad   Not Available   4 GB   LPDDR4
# 633  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 634  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 635  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
#
#         ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
asus_4gb=asus_intl[asus_intl['ram_gb']=='4 GB']

# %%
asus_4gb
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 14   ASUS           Intel        Core i3            11th   4 GB     DDR4
# 20   ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 21   ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 24   ASUS           Intel        Core i3            11th   4 GB     DDR4
# 26   ASUS           Intel        Core i3            11th   4 GB     DDR4
# 60   ASUS           Intel        Core i3            10th   4 GB     DDR4
# 66   ASUS           Intel        Core i3            11th   4 GB     DDR4
# 68   ASUS           Intel        Core i3            11th   4 GB     DDR4
# ...

# %%
asus_4gb_touch=asus_4gb[asus_4gb['Touchscreen']=='Yes']

# %%
asus_4gb_touch
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 624  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
#
#         ssd   hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 624  128 GB  0 GB  Windows  32-bit            0 GB  Casual  No warranty
#
#     Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# 624         Yes       No  58100  3 stars                  0                  0

# %%
total=total.drop(['weight','warranty','msoffice','rating','Number of Ratings','Number of Reviews'],axis=1)

# %%
total
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
total
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
total['Touchscreen'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
touch_dict={
    'No':0,'Yes':1
}

# %%
total['Touchscreen'] = total['Touchscreen'].map(touch_dict)

# %%
total
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
total['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
proccessor_brand_dict={
    'Intel':0,
    'AMD':1,
    'M1':2
}

# %%
ssd_dict ={
    '0 GB':0,
    '512 GB':512,
    '256 GB':256,
    '128 GB':128,
    '1024 GB':1024,
    '2048 GB':2048,
    '3072 GB':3072
}

# %%
ram_type_dict ={
    'DDR4':0,
    'LPDDR4':1,
    'LPDDR4X':2,
    'DDR5':3,
    'DDR3':4,
    'LPDDR3':5
}

# %%
total['processor_brand']=total['processor_brand'].map(proccessor_brand_dict)

# %%
total
# Out:
#       brand  processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS                0        Core i3            10th   4 GB     DDR4
# 1    Lenovo                0        Core i3            10th   4 GB     DDR4
# 2    Lenovo                0        Core i3            10th   4 GB     DDR4
# 3      ASUS                0        Core i5            10th   8 GB     DDR4
# 4      ASUS                0   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...              ...            ...             ...    ...      ...
# 818    ASUS                1        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS                1        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS                1        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS                1        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo                1        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 802 entries, 0 to 822
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            802 non-null    object
#  1   processor_brand  802 non-null    int64
#  2   processor_name   802 non-null    object
#  3   processor_gnrtn  802 non-null    object
#  4   ram_gb           802 non-null    object
#  5   ram_type         802 non-null    object
#  6   ssd              802 non-null    object
#  7   hdd              802 non-null    object
#  8   os               802 non-null    object
#  9   os_bit           802 non-null    object
#  10  graphic_card_gb  802 non-null    object
#  11  Touchscreen      802 non-null    int64
#  12  Price            802 non-null    int64
# dtypes: int64(3), object(10)
# memory usage: 87.7+ KB
